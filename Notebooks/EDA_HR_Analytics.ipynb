# %%
# Import Packages

# Array and Dataframe processing:
import pandas as pd
import numpy as np

# Visualization:
import seaborn as sns
sns.set_style("darkgrid")
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.graph_objects as go
import plotly.express as px
import plotly.figure_factory as ff

import pandas as pd
import mysql.connector

# %%
# # Model Implementation 
# from sklearn.ensemble import RandomForestClassifier
# from sklearn import svm
# from sklearn.svm import SVC
# from sklearn.neural_network import MLPClassifier
# # from sklearn.linear_model import SGDCClassifier

# #  Metrics 
# from sklearn.metrics import confusion_matrix, classification_report
# from sklearn.metrics import accuracy_score

# # For scaling and preprocessing:  StandardScaler, MinMaxScaler and MaxAbsScaler.
# from sklearn import preprocessing
# from sklearn.preprocessing import StandardScaler, LabelEncoder

# # For Model Training and Testing:
# from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../Data/HR_Data.csv')
df
# Out:
#             Employee_Name         EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0              Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1    LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2        Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3         Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4             Singh, Nan   1.307060e+09        0.0              0.0       0.0
# ..                    ...           ...        ...              ...       ...
# 396                   NaN           NaN        NaN              NaN       NaN
# 397                   NaN           NaN        NaN              NaN       NaN
# 398                   NaN           NaN        NaN              NaN       NaN
# 399                   NaN           NaN        NaN              NaN       NaN
# 400                   NaN           NaN        NaN              NaN       NaN
#
# ...

# %%
dic = pd.read_excel('../Data/data_dictionary.xlsx')
dic
# Out:
#                       Feature  \
# 0               Employee Name
# 1                       EmpID
# 2                   MarriedID
# 3             MaritalStatusID
# 4                 EmpStatusID
# 5                      DeptID
# 6                 PerfScoreID
# 7      FromDiversityJobFairID
# 8                     PayRate
# 9                       Termd
# 10                 PositionID
# 11                   Position
# 12                      State
# 13                        Zip
# 14                        DOB
# 15                        Sex
# 16                MaritalDesc
# 17                CitizenDesc
# 18             HispanicLatino
# 19                   RaceDesc
# 20                 DateofHire
# 21          DateofTermination
# 22                 TermReason
# 23           EmploymentStatus
# 24                 Department
# 25                ManagerName
# 26                  ManagerID
# 27          RecruitmentSource
# 28           PerformanceScore
# 29           EngagementSurvey
# ...

# %%
import sql_config
config = sql_config
print(cnx)

# %%
# CREATE TABLE `schema_employee_attrition`.`new_table` (
#   `id` INT NOT NULL,
#   `one` VARCHAR(45) NOT NULL,
#   `two` INT NOT NULL,
#   PRIMARY KEY (`id`),
#   UNIQUE INDEX `id_UNIQUE` (`id` ASC));

# %%
def execute_sql(action):
    cnx = mysql.connector.connect(host = config.host, user = config.user, password = config.password)
    print(cnx)
    cursor = cnx.cursor(buffered = True)
    cursor.execute(query)
    df = pd.DataFrame(cursor.fetchall())
    cursor.description
    df.columns = [x[0] for x in cursor.description]
    return df.head()

# %%
action = ("""create table hr_analytics.employee_data(
EmpID int not null,
Employee Name varchar not null,
MarriedID int not null,
MaritalStatusID int not null,
EmpStatusID int not null,
DeptID int not null,
PerfScoreID int not null,
FromDiversityJobFairID int not null,
PayRate float not null,
Termd
PositionID
Position
State
Zip
DOB
Sex
MaritalDesc
CitizenDesc
HispanicLatino
RaceDesc
DateofHire
DateofTermination
TermReason
EmploymentStatus
Department
ManagerName
ManagerID
RecruitmentSource
PerformanceScore
EngagementSurvey
EmpSatisfaction
SpecialProjectsCount
LastPerformanceReviewDate
DaysLateLast30)


""")
